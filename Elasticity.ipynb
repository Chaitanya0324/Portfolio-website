# %%
import threading
import time
import queue

def process_task(task_id):
    print(f"Processing Task {task_id}")
    time.sleep(1)
    print(f"Task {task_id} completed")

def worker(task_queue,thread_id):
    while True:
        try:
            task_id = task_queue.get(timeout=2)
            print(f"[Thread-{thread_id}]picked Task-{task_id}")
            process_task(task_id)
            task_queue.task_done()
        except queue.Empty:
            print(f"[Threads-{thread_id}]no more tasks. Existing...")
            break

def simulate_elasticity():
    task_queue = queue.Queue()
    for i in range(5):
        task_queue.put(i)

    num_threads = 2
    threads = []
    print("\nStarting with 2 worker threads...\n")

    for t_id in range(num_threads):
        t = threading.Thread(target=worker, args=(task_queue,t_id))
        t.start()
        threads.append(t)

    time.sleep(3)
    print("\nWorkload increased! Adding more tasks and more threads...\n")

    for i in range(5,15):
        task_queue.put(i)

    for t_id in range(2,5):
        t = threading.Thread(target=worker, args=(task_queue,t_id))
        t.start()
        threads.append(t)

    for t in threads:
        t.join()

        print("\nAll tasks completed. Resources scaled elasticity.\n")

simulate_elasticity()
# Out:
# Starting with 2 worker threads...
#
# [Thread-0]picked Task-0
# Processing Task 0
# [Thread-1]picked Task-1
# Processing Task 1
# Task 0 completedTask 1 completed
# [Thread-1]picked Task-2
# Processing Task 2
#
# [Thread-0]picked Task-3
# Processing Task 3
# Task 2 completed
# [Thread-1]picked Task-4
# Processing Task 4
# Task 3 completed
#
# Workload increased! Adding more tasks and more threads...
#
# [Thread-2]picked Task-5
# Processing Task 5
# [Thread-0]picked Task-6
# Processing Task 6
# [Thread-3]picked Task-7
# Processing Task 7
# [Thread-4]picked Task-8
# Processing Task 8
# Task 4 completed
# [Thread-1]picked Task-9
# Processing Task 9
# Task 6 completedTask 5 completed
# [Thread-2]picked Task-10
# Processing Task 10
#
# [Thread-0]picked Task-11
# Processing Task 11
# Task 7 completed
# [Thread-3]picked Task-12
# Processing Task 12
# Task 8 completed
# [Thread-4]picked Task-13
# Processing Task 13
# Task 9 completed
# [Thread-1]picked Task-14
# Processing Task 14
# Task 10 completedTask 13 completed
# Task 14 completed
#
# Task 11 completed
# Task 12 completed
# [Threads-4]no more tasks. Existing...[Threads-0]no more tasks. Existing...
# [Threads-3]no more tasks. Existing...
#
# [Threads-2]no more tasks. Existing...
# [Threads-1]no more tasks. Existing...
#
# All tasks completed. Resources scaled elasticity.
#
#
# All tasks completed. Resources scaled elasticity.
#
#
# All tasks completed. Resources scaled elasticity.
#
#
# All tasks completed. Resources scaled elasticity.
#
#
# All tasks completed. Resources scaled elasticity.
